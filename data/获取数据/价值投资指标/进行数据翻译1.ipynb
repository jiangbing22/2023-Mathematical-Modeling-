# %%
import os  
import pandas as pd  
  
# 定义列名对应关系  
column_mapping = {  
    "code": "证券代码",  
    "pubDate": "公司发布财报的日期",  
    "statDate": "财报统计的季度的最后一天",  
    "currentRatio": "流动比率",  
    "quickRatio": "速动比率",  
    "cashRatio": "现金比率",  
    "YOYLiability": "总负债同比增长率",  
    "liabilityToAsset": "资产负债率",  
    "assetToEquity": "权益乘数",  
    "year": "年份",  # 根据您的描述添加  
    "quarter": "季度"  # 根据您的描述添加  
}  
  
# 遍历文件夹中的每个Excel文件  
folder_path = "非国企深市的季频偿债能力"  # 请替换为您的文件夹路径  
for filename in os.listdir(folder_path):  
    if filename.endswith(".xlsx"):  
        file_path = os.path.join(folder_path, filename)  
          
        # 读取Excel文件  
        df = pd.read_excel(file_path)  
          
        # 修改列名  
        df.columns = [column_mapping[col] for col in df.columns]  
          
        # 写回Excel文件，index=False表示不写入行索引  
        df.to_excel(file_path, index=False)

# %%
import os  
import pandas as pd  
  
# 定义列名对应关系  
column_mapping = {  
    "code": "证券代码",  
    "pubDate": "公司发布财报的日期",  
    "statDate": "财报统计的季度的最后一天",  
    "CAToAsset":"流动资产除以总资产",
    "NCAToAsset":"流动资产除以总资产",
    "tangibleAssetToAsset":"有形资产除以总资产",
    "ebitToInterest": "已获利息倍数",
    "CFOToOR":"经营活动产生的现金流量净额除以营业收入",
    "CFOToNP":"经营性现金净流量除以净利润",
    "CFOToGr":"	经营性现金净流量除以营业总收入",
    "year": "年份",  # 根据您的描述添加  
    "quarter": "季度"  # 根据您的描述添加  
}  
  
# 遍历文件夹中的每个Excel文件  
folder_path = "国企深市的季频现金流数据"  # 请替换为您的文件夹路径  
for filename in os.listdir(folder_path):  
    if filename.endswith(".xlsx"):  
        file_path = os.path.join(folder_path, filename)  
          
        # 读取Excel文件  
        df = pd.read_excel(file_path)  
          
        # 修改列名  
        df.columns = [column_mapping[col] for col in df.columns]  
          
        # 写回Excel文件，index=False表示不写入行索引  
        df.to_excel(file_path, index=False)

# %%
import os  
import pandas as pd  
  
# 定义列名对应关系  
column_mapping = {  
    "code": "证券代码",  
    "pubDate": "公司发布财报的日期",  
    "statDate": "财报统计的季度的最后一天",  
    "CAToAsset":"流动资产除以总资产",
    "NCAToAsset":"流动资产除以总资产",
    "tangibleAssetToAsset":"有形资产除以总资产",
    "ebitToInterest": "已获利息倍数",
    "CFOToOR":"经营活动产生的现金流量净额除以营业收入",
    "CFOToNP":"经营性现金净流量除以净利润",
    "CFOToGr":"	经营性现金净流量除以营业总收入",
    "year": "年份",  # 根据您的描述添加  
    "quarter": "季度"  # 根据您的描述添加  
}  
  
# 遍历文件夹中的每个Excel文件  
folder_path = "国企沪市的季频现金流数据"  # 请替换为您的文件夹路径  
for filename in os.listdir(folder_path):  
    if filename.endswith(".xlsx"):  
        file_path = os.path.join(folder_path, filename)  
          
        # 读取Excel文件  
        df = pd.read_excel(file_path)  
          
        # 修改列名  
        df.columns = [column_mapping[col] for col in df.columns]  
          
        # 写回Excel文件，index=False表示不写入行索引  
        df.to_excel(file_path, index=False)

# %%
import os  
import pandas as pd  
  
# 定义列名对应关系  
column_mapping = {  
    "code": "证券代码",  
    "pubDate": "公司发布财报的日期",  
    "statDate": "财报统计的季度的最后一天",  
    "roeAvg":"净资产收益率(平均)(%)",
    "npMargin":"销售净利率(%)",
    "gpMargin":"销售毛利率(%)",
    "netProfit": "净利润(元)",
    "epsTTM":"每股收益",
    "MBRevenue":"主营营业收入(元)",
    "totalShare":"总股本",
    "liqaShare": "流通股本",
    "year": "年份",  # 根据您的描述添加  
    "quarter": "季度"  # 根据您的描述添加  
}  
  
# 遍历文件夹中的每个Excel文件  
folder_path = "国企深市的季频盈利能力"  # 请替换为您的文件夹路径  
for filename in os.listdir(folder_path):  
    if filename.endswith(".xlsx"):  
        file_path = os.path.join(folder_path, filename)  
          
        # 读取Excel文件  
        df = pd.read_excel(file_path)  
          
        # 修改列名  
        df.columns = [column_mapping[col] for col in df.columns]  
          
        # 写回Excel文件，index=False表示不写入行索引  
        df.to_excel(file_path, index=False)

# %%
import os  
import pandas as pd  
  
# 设置原始文件夹和新的目标文件夹  
source_folders = ['非国企沪市的季频偿债能力', '非国企沪市的季频现金流数据', '非国企沪市的季频盈利能力']  
target_folder = '非国企沪市的三合一'  
  
# 确保目标文件夹存在  
if not os.path.exists(target_folder):  
    os.makedirs(target_folder)  
  
# 定义共同的列名  
common_columns = ['证券代码', '公司发布财报的日期', '财报统计的季度的最后一天', '年份', '季度']  
  
merged_df = pd.DataFrame()  # 初始化一个空的DataFrame  
  
# 定义一个函数来为冲突的列名添加后缀  
def add_suffix_to_columns(df, suffix):  
    new_columns = {}  
    for col in df.columns:  
        new_columns[col] = col + suffix  
    df.columns = new_columns  
    return df  
  
# 遍历每个原始文件夹  
for folder in source_folders:  
    for filename in os.listdir(folder):  
        if filename.endswith('.xlsx'):  
            filepath = os.path.join(folder, filename)  
            df = pd.read_excel(filepath)  
              
            # 检查当前文件中的列名是否与已合并的DataFrame中的列名冲突  
            conflicting_columns = set(df.columns) & set(merged_df.columns) - set(common_columns)  
              
            # 如果有冲突，为冲突的列名添加文件名的后缀  
            if conflicting_columns:  
                suffix = '_' + os.path.splitext(os.path.basename(filepath))[0]  
                df = add_suffix_to_columns(df, suffix)  
              
            # 只保留共同的列和其他独有的列  
            df = df[common_columns + [col for col in df.columns if col not in common_columns and col not in merged_df.columns]]  
              
            # 使用outer merge合并数据  
            if merged_df.empty:  
                merged_df = df  
            else:  
                merged_df = pd.merge(merged_df, df, on=common_columns, how='outer')  
            # 将当前的文件名作为目标文件名  
            target_file = filename  # 更新目标文件名为当前文件名  

# 将合并后的数据保存到目标文件夹中，使用指定的文件名  
merged_df.to_excel(os.path.join(target_folder, target_file), index=False)  
  
print("合并完成！")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\桌面\大湾区金融数模\2023-Mathematical-Modeling-\data\获取数据\价值投资指标\进行数据翻译1.ipynb 单元格 5 line 4
#      <a href='vscode-notebook-cell:/d%3A/%E6%A1%8C%E9%9D%A2/%E5%A4%A7%E6%B9%BE%E5%8C%BA%E9%87%91%E8%9E%8D%E6%95%B0%E6%A8%A1/2023-Mathematical-Modeling-/data/%E8%8E%B7%E5%8F%96%E6%95%B0%E6%8D%AE/%E4%BB%B7%E5%80%BC%E6%8A%95%E8%B5%84%E6%8C%87%E6%A0%87/%E8%BF%9B%E8%A1%8C%E6%95%B0%E6%8D%AE%E7%BF%BB%E8%AF%911.ipynb#W4sZmlsZQ%3D%3D?line=37'>38</a>     df = add_suffix_to_columns(df, suffix)
#      <a href='vscode-notebook-cell:/d%3A/%E6%A1%8C%E9%9D%A2/%E5%A4%A7%E6%B9%BE%E5%8C%BA%E9%87%91%E8%9E%8D%E6%95%B0%E6%A8%A1/2023-Mathematical-Modeling-/data/%E8%8E%B7%E5%8F%96%E6%95%B0%E6%8D%AE/%E4%BB%B7%E5%80%BC%E6%8A%95%E8%B5%84%E6%8C%87%E6%A0%87/%E8%BF%9B%E8%A1%8C%E6%95%B0%E6%8D%AE%E7%BF%BB%E8%AF%911.ipynb#W4sZmlsZQ%3D%3D?line=39'>40</a> # 只保留共同的列和其他独有的列
# ---> <a href='vscode-notebook-cell:/d%3A/%E6%A1%8C%E9%9D%A2/%E5%A4%A7%E6%B9%BE%E5%8C%BA%E9%87%91%E8%9E%8D%E6%95%B0%E6%A8%A1/2023-Mathematical-Modeling-/data/%E8%8E%B7%E5%8F%96%E6%95%B0%E6%8D%AE/%E4%BB%B7%E5%80%BC%E6%8A%95%E8%B5%84%E6%8C%87%E6%A0%87/%E8%BF%9B%E8%A1%8C%E6%95%B0%E6%8D%AE%E7%BF%BB%E8%AF%911.ipynb#W4sZmlsZQ%3D%3D?line=40'>41</a> df = df[common_columns + [col for col in df.columns if col not in common_columns and col not in merged_df.columns]]
#      <a href='vscode-notebook-cell:/d%3A/%E6%A1%8C%E9%9D%A2/%E5%A4%A7%E6%B9%BE%E5%8C%BA%E9%87%91%E8%9E%8D%E6%95%B0%E6%A8%A1/2023-Mathematical-Modeling-/data/%E8%8E%B7%E5%8F%96%E6%95%B0%E6%8D%AE/%E4%BB%B7%E5%80%BC%E6%8A%95%E8%B5%84%E6%8C%87%E6%A0%87/%E8%BF%9B%E8%A1%8C%E6%95%B0%E6%8D%AE%E7%BF%BB%E8%AF%911.ipynb#W4sZmlsZQ%3D%3D?line=42'>43</a> # 使用outer merge合并数据
#      <a href='vscode-notebook-cell:/d%3A/%E6%A1%8C%E9%9D%A2/%E5%A4%A7%E6%B9%BE%E5%8C%BA%E9%87%91%E8%9E%8D%E6%95%B0%E6%A8%A1/2023-Mathematical-Modeling-/data/%E8%8E%B7%E5%8F%96%E6%95%B0%E6%8D%AE/%E4%BB%B7%E5%80%BC%E6%8A%95%E8%B5%84%E6%8C%87%E6%A0%87/%E8%BF%9B%E8%A1%8C%E6%95%B0%E6%8D%AE%E7%BF%BB%E8%AF%911.ipynb#W4sZmlsZQ%3D%3D?line=43'>44</a> if merged_df.empty:
#
# File d:\Anaconda\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File d:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File d:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['公司发布财报的日期', '财报统计的季度的最后一天'] not in index"

# %%
import os  
import pandas as pd  
  
# 定义一个空的DataFrame，用于存储最终的数据  
all_data = pd.DataFrame()  
  
# 遍历文件夹中的所有Excel文件  
folder_path = '非国有价值投资指标数据'  # 你的文件夹路径  
for filename in os.listdir(folder_path):  
    if filename.endswith((".xlsx", ".xls")):  # 使用元组检查多个后缀  
        file_path = os.path.join(folder_path, filename)  
  
        # 读取Excel文件的内容，不包含列名（因为所有文件的列名都一样）  
        df = pd.read_excel(file_path, header=None, skiprows=1)  
  
        # 如果df有多行数据，你可以在这里加入处理代码，当前代码只处理单行数据  
  
        # 将数据追加到all_data DataFrame中  
        all_data = all_data.append(df, ignore_index=True)  
  
# 重命名列名，因为读取时没有列名，所以需要重新设置  
all_data.columns = ["股票代码", "股票名称", "净利润", "总市值", "流通市值", "所处行业", "市盈率(动)", "市净率", "ROE", "毛利率", "净利率", "板块编号"]  
  
# 将结果保存为一个新的Excel文件  
all_data.to_excel("非国有价值投资指标合并数据.xlsx", index=False)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_35280\3771690712.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = all_data.append(df, ignore_index=True)

# %%
import os  
import pandas as pd  
  
# 读取原始Excel文件  
original_file = '非国有价值投资指标合并数据.xlsx'  # 替换为你的原始Excel文件路径  
df = pd.read_excel(original_file)  
  
# 指定要保存新Excel文件的文件夹路径  
save_folder = '非国有每个行业抽10个'  # 替换为你要保存新Excel文件的文件夹路径  
  
# 筛选每个行业的股票，并抽取10个数据  
unique_industries = df['所处行业'].unique()  
for industry in unique_industries:  
    # 筛选指定行业的股票数据  
    industry_data = df[df['所处行业'] == industry].head(10)  # 使用head(10)抽取前10个数据  
  
    # 生成新的Excel文件名并保存到指定文件夹  
    new_file_name = f'{industry}_top10.xlsx'  
    new_file_path = os.path.join(save_folder, new_file_name)  
  
    # 将筛选后的数据保存到新的Excel文件  
    industry_data.to_excel(new_file_path, index=False)

# %%
import os  
import pandas as pd  
   
folder1 = '非国企沪市的季频偿债能力'  
folder2 = '非国企沪市的季频现金流数据'  
folder3 = '非国企沪市的季频盈利能力'  
  

output_folder = '非国企沪市的三合一'  
  

security_codes = os.listdir(folder1)  
# security_codes
# for security_code in security_codes:  
#     # print(security_code)
#     # 检查该文件是否在三个文件夹中都存在  
#     file1_path = os.path.join(folder1, security_code)  
#     file2_path = os.path.join(folder2, security_code)  
#     file3_path = os.path.join(folder3, security_code)  
#     if os.path.isfile(file1_path) and os.path.isfile(file2_path) and os.path.isfile(file3_path):  
#         # 如果是Excel文件（这里假设所有文件都是.xlsx格式）  
#         if file1_path.endswith('.xlsx') and file2_path.endswith('.xlsx') and file3_path.endswith('.xlsx'):  
#             # 从三个Excel文件中抽取指定列  
#             # 从第一个表格中抽取指定列  
#             file1_columns = ["年份", "季度", "证券代码", "公司发布财报的日期", "财报统计的季度的最后一天", "流动比率", "速动比率", "现金比率", "总负债同比增长率", "资产负债率", "权益乘数"]  
#             file1 = pd.read_excel(f"{security_code}", usecols=file1_columns)   
#             # 从第二个表格中抽取指定列  
#             file2_columns = ["流动资产除以总资产", "有形资产除以总资产", "已获利息倍数", "经营活动产生的现金流量净额除以营业收入", "经营性现金净流量除以净利润", "	经营性现金净流量除以营业总收入"]  
#             file2 = pd.read_excel(f"{security_code}", usecols=file2_columns) 
#             # 从第三个表格中抽取指定列  
#             file3_columns = ["净资产收益率(平均)(%)", "销售净利率(%)", "销售毛利率(%)", "净利润(元)", "每股收益", "主营营业收入(元)", "总股本", "流通股本"]  
#             file3 = pd.read_excel(f"{security_code}", usecols=file3_columns)                          
            
#             file1 = pd.read_excel(file1_path, usecols=file1_columns)  
#             file2 = pd.read_excel(file2_path, usecols=file2_columns)  
#             file3 = pd.read_excel(file3_path, usecols=file3_columns)  
      
#             # 使用pd.concat()函数将三个DataFrame横向合并  
#             merged_df = pd.concat([file1, file2, file3], axis=1)  
              
#             # 将合并后的DataFrame保存到新的Excel文件中，并存放到指定的文件夹  
#             output_path = os.path.join(output_folder, f"{security_code}")  
#             merged_df.to_excel(output_path, index=False)
for security_code in security_codes:    
    # 初始化一个标志变量，用于记录三个文件是否都存在  
    all_files_exist = True  
  
    # 检查文件是否在三个文件夹中都存在    
    file1_path = os.path.join(folder1, security_code)    
    file2_path = os.path.join(folder2, security_code)    
    file3_path = os.path.join(folder3, security_code)    
  
    # 检查三个文件是否存在，并且是否是Excel文件  
    if not (os.path.isfile(file1_path) and os.path.isfile(file2_path) and os.path.isfile(file3_path)):    
        all_files_exist = False  
    else:  
        # 如果是Excel文件（这里假设所有文件都是.xlsx格式）    
        if not (file1_path.endswith('.xlsx') and file2_path.endswith('.xlsx') and file3_path.endswith('.xlsx')):    
            all_files_exist = False  
  
    # 如果所有文件都存在，才执行后续的操作  
    if all_files_exist:  
        # 从三个Excel文件中抽取指定列    
        # 从第一个表格中抽取指定列
         
        file1_columns = ["年份", "季度", "证券代码", "公司发布财报的日期", "财报统计的季度的最后一天", "流动比率", "速动比率", "现金比率", "总负债同比增长率", "资产负债率", "权益乘数"]  
        try: 
            file1 = pd.read_excel(file1_path, usecols=file1_columns)  
        except:
            print(f"{file1_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第二个表格中抽取指定列  
        
        file2_columns = ["流动资产除以总资产", "有形资产除以总资产", "已获利息倍数", "经营活动产生的现金流量净额除以营业收入", "经营性现金净流量除以净利润", "	经营性现金净流量除以营业总收入"]  
        try: 
            file2 = pd.read_excel(file2_path, usecols=file2_columns) 
        except:
            print(f"{file2_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第三个表格中抽取指定列  
        file3_columns = ["净资产收益率(平均)(%)", "销售净利率(%)", "销售毛利率(%)", "净利润(元)", "每股收益", "主营营业收入(元)", "总股本", "流通股本"]  
        try:
            file3 = pd.read_excel(file3_path, usecols=file3_columns) 
        except: 
            print(f"{file3_path}缺少一些列，从而跳过处理...") 
            continue      
        
        # file1 = pd.read_excel(file1_path, usecols=file1_columns)     
        # file2 = pd.read_excel(file2_path, usecols=file2_columns)   
        # file3 = pd.read_excel(file3_path, usecols=file3_columns)                            
              
        # 使用pd.concat()函数将三个DataFrame横向合并    
        merged_df = pd.concat([file1, file2, file3], axis=1)    
                
        # 将合并后的DataFrame保存到新的Excel文件中，并存放到指定的文件夹    
        output_path = os.path.join(output_folder, f"{security_code}")    
        merged_df.to_excel(output_path, index=False)  
    else:  
        print(f"One or more files for {security_code} do not exist. Skipping...")  
        continue
# Out:
# 非国企沪市的季频偿债能力\sh.600055.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600066.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600071.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600078.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600084.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600088.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600107.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600191.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600193.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600196.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600207.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600217.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600221.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600222.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600282.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600358.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600379.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600387.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600398.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600408.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600422.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600449.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600530.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600589.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600624.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600633.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600635.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600655.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600657.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600662.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600671.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600678.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600702.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600706.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600721.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600730.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600776.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600817.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600836.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600854.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600862.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600867.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600872.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600885.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600892.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600905.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600927.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600933.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600936.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600938.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.600941.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600961.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600968.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600970.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600973.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600986.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600989.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600990.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.600995.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601005.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601006.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601010.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601019.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.601028.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601059.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.601061.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.601089.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601127.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.601133.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601156.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601163.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601177.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601199.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601233.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601236.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601319.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601333.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601360.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601375.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601579.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601599.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.601606.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601608.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601619.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601633.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601658.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601698.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601816.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601858.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601877.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601878.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601900.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601901.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.601921.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601929.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601949.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.601998.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603000.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603007.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603010.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603011.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603012.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603013.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603017.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603019.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603023.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603029.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603032.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603041.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603042.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603050.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603056.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603059.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603060.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603063.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603067.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603078.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603083.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603093.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603110.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603116.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603117.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603128.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603150.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603159.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603160.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603168.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603171.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603186.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603187.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603189.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603196.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603198.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603201.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603213.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603215.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603217.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603226.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603236.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603239.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603275.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603296.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603302.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603303.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603309.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603318.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603329.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603333.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603355.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603358.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603368.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603386.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603392.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603393.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603398.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603399.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603439.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603444.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603477.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603489.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603501.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603506.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603511.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603517.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603519.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603528.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603555.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603556.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603557.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603565.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603577.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603583.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603586.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603588.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603601.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603633.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603650.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603658.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603659.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603660.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603661.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603662.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603682.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603685.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603688.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603696.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603698.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603708.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603716.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603718.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603755.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603759.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603773.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603776.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.603800.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603836.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603856.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603860.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603869.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603886.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603888.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603889.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603890.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603893.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603912.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603919.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603920.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603922.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603933.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603939.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603970.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603978.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603980.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603982.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603991.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.603998.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605005.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605008.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.605056.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.605069.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605081.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.605089.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605116.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605117.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605136.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605178.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605218.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605255.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605259.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605277.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605287.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605303.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605358.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605368.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605376.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.605488.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605499.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.605567.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频偿债能力\sh.605577.xlsx缺少一些列，从而跳过处理...
# 非国企沪市的季频现金流数据\sh.605588.xlsx缺少一些列，从而跳过处理...

# %%
import os  
import pandas as pd  
   
folder1 = '非国企深市的季频偿债能力'  
folder2 = '非国企深市的季频现金流数据'  
folder3 = '非国企深市的季频盈利能力'  
  

output_folder = '非国企深市的三合一'  
  

security_codes = os.listdir(folder1)  
for security_code in security_codes:    
    # 初始化一个标志变量，用于记录三个文件是否都存在  
    all_files_exist = True  
  
    # 检查文件是否在三个文件夹中都存在    
    file1_path = os.path.join(folder1, security_code)    
    file2_path = os.path.join(folder2, security_code)    
    file3_path = os.path.join(folder3, security_code)    
  
    # 检查三个文件是否存在，并且是否是Excel文件  
    if not (os.path.isfile(file1_path) and os.path.isfile(file2_path) and os.path.isfile(file3_path)):    
        all_files_exist = False  
    else:  
        # 如果是Excel文件（这里假设所有文件都是.xlsx格式）    
        if not (file1_path.endswith('.xlsx') and file2_path.endswith('.xlsx') and file3_path.endswith('.xlsx')):    
            all_files_exist = False  
  
    # 如果所有文件都存在，才执行后续的操作  
    if all_files_exist:  
        # 从三个Excel文件中抽取指定列    
        # 从第一个表格中抽取指定列
         
        file1_columns = ["年份", "季度", "证券代码", "公司发布财报的日期", "财报统计的季度的最后一天", "流动比率", "速动比率", "现金比率", "总负债同比增长率", "资产负债率", "权益乘数"]  
        try: 
            file1 = pd.read_excel(file1_path, usecols=file1_columns)  
        except:
            print(f"{file1_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第二个表格中抽取指定列  
        
        file2_columns = ["流动资产除以总资产", "有形资产除以总资产", "已获利息倍数", "经营活动产生的现金流量净额除以营业收入", "经营性现金净流量除以净利润", "	经营性现金净流量除以营业总收入"]  
        try: 
            file2 = pd.read_excel(file2_path, usecols=file2_columns) 
        except:
            print(f"{file2_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第三个表格中抽取指定列  
        file3_columns = ["净资产收益率(平均)(%)", "销售净利率(%)", "销售毛利率(%)", "净利润(元)", "每股收益", "主营营业收入(元)", "总股本", "流通股本"]  
        try:
            file3 = pd.read_excel(file3_path, usecols=file3_columns) 
        except: 
            print(f"{file3_path}缺少一些列，从而跳过处理...") 
            continue      
        
        # file1 = pd.read_excel(file1_path, usecols=file1_columns)     
        # file2 = pd.read_excel(file2_path, usecols=file2_columns)   
        # file3 = pd.read_excel(file3_path, usecols=file3_columns)                            
              
        # 使用pd.concat()函数将三个DataFrame横向合并    
        merged_df = pd.concat([file1, file2, file3], axis=1)    
                
        # 将合并后的DataFrame保存到新的Excel文件中，并存放到指定的文件夹    
        output_path = os.path.join(output_folder, f"{security_code}")    
        merged_df.to_excel(output_path, index=False)  
    else:  
        print(f"One or more files for {security_code} do not exist. Skipping...")  
        continue
# Out:
# 非国企深市的季频盈利能力\sz.000001.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000004.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000012.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000017.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000021.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000036.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000066.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000159.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000407.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000509.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000592.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000609.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000632.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000633.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000638.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000695.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000702.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000757.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000766.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000831.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000839.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.000877.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000889.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000892.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000980.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.000981.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001201.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001202.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001205.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001213.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001215.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001217.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001231.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001270.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001283.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001286.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001287.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001300.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001318.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001319.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001337.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001360.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.001366.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.001965.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002006.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002017.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002021.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002036.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002046.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002072.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002121.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002159.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002168.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002172.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002190.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002196.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002231.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002238.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002239.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002240.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002244.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002247.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002248.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002250.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002253.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002255.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002258.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002259.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002261.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002264.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002266.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002268.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002269.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002273.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002280.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002283.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002286.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002287.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002289.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002293.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002298.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002307.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002309.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002311.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002313.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002314.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002315.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002316.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002319.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002321.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002324.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002325.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002328.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002329.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002330.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002331.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002333.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002335.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002337.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002338.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002341.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002350.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002352.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002355.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002356.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002357.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002360.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002365.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002367.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002369.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002371.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002377.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002382.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002385.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002388.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002391.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002395.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002397.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002398.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002402.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002404.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002408.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002410.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002414.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002415.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002416.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002418.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002421.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002426.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002429.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002431.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002432.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002436.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002438.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002442.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002443.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002446.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002448.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002449.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002453.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002454.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002458.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002459.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002462.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002467.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002469.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002471.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002476.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002478.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002484.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002485.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002492.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002496.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002498.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002500.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002501.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002502.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002505.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002506.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002513.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002514.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002515.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002516.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002525.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002529.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002534.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002538.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002545.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002546.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002550.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002555.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002558.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002566.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002567.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002568.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002569.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002570.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002575.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002577.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002578.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002581.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002585.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002598.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002600.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002601.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002606.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002610.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002620.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002621.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002622.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002624.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002625.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002626.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002628.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002629.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002630.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002631.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002636.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002637.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002643.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002646.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002658.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002663.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002667.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002668.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002670.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002671.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002674.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002675.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002679.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002683.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002689.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002690.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002691.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002694.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002699.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002700.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002701.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002702.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002705.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002707.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002713.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002715.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002716.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002717.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002720.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002723.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002727.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002729.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002731.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002732.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002737.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002743.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002745.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002747.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002750.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002756.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002760.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002763.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002769.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002777.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002780.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002785.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002786.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002788.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002795.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002801.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002802.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002803.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002805.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002806.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002808.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002809.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002816.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002818.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002819.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002824.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002825.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002826.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002837.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002843.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002849.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002852.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002853.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002855.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002857.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002863.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002864.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002868.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002869.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002870.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002872.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002873.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002876.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002877.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002879.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002880.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002899.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002908.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002909.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002910.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002915.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002916.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002919.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002921.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002922.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002925.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002930.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002931.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002939.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002945.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002952.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002957.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002962.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002977.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002978.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002980.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002985.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002986.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.002989.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002990.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002991.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002997.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.002999.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.003002.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.003006.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.003009.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.003019.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.003020.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频偿债能力\sz.003031.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.003038.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.003041.xlsx缺少一些列，从而跳过处理...
# 非国企深市的季频盈利能力\sz.003042.xlsx缺少一些列，从而跳过处理...

# %%
import os  
import pandas as pd  
   
folder1 = '国企深市的季频偿债能力'  
folder2 = '国企深市的季频现金流数据'  
folder3 = '国企深市的季频盈利能力'  
  

output_folder = '国企深市的三合一'  
  

security_codes = os.listdir(folder1)  
for security_code in security_codes:    
    # 初始化一个标志变量，用于记录三个文件是否都存在  
    all_files_exist = True  
  
    # 检查文件是否在三个文件夹中都存在    
    file1_path = os.path.join(folder1, security_code)    
    file2_path = os.path.join(folder2, security_code)    
    file3_path = os.path.join(folder3, security_code)    
  
    # 检查三个文件是否存在，并且是否是Excel文件  
    if not (os.path.isfile(file1_path) and os.path.isfile(file2_path) and os.path.isfile(file3_path)):    
        all_files_exist = False  
    else:  
        # 如果是Excel文件（这里假设所有文件都是.xlsx格式）    
        if not (file1_path.endswith('.xlsx') and file2_path.endswith('.xlsx') and file3_path.endswith('.xlsx')):    
            all_files_exist = False  
  
    # 如果所有文件都存在，才执行后续的操作  
    if all_files_exist:  
        # 从三个Excel文件中抽取指定列    
        # 从第一个表格中抽取指定列
         
        file1_columns = ["年份", "季度", "证券代码", "公司发布财报的日期", "财报统计的季度的最后一天", "流动比率", "速动比率", "现金比率", "总负债同比增长率", "资产负债率", "权益乘数"]  
        try: 
            file1 = pd.read_excel(file1_path, usecols=file1_columns)  
        except:
            print(f"{file1_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第二个表格中抽取指定列  
        
        file2_columns = ["流动资产除以总资产", "有形资产除以总资产", "已获利息倍数", "经营活动产生的现金流量净额除以营业收入", "经营性现金净流量除以净利润", "	经营性现金净流量除以营业总收入"]  
        try: 
            file2 = pd.read_excel(file2_path, usecols=file2_columns) 
        except:
            print(f"{file2_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第三个表格中抽取指定列  
        file3_columns = ["净资产收益率(平均)(%)", "销售净利率(%)", "销售毛利率(%)", "净利润(元)", "每股收益", "主营营业收入(元)", "总股本", "流通股本"]  
        try:
            file3 = pd.read_excel(file3_path, usecols=file3_columns) 
        except: 
            print(f"{file3_path}缺少一些列，从而跳过处理...") 
            continue      
        
        # file1 = pd.read_excel(file1_path, usecols=file1_columns)     
        # file2 = pd.read_excel(file2_path, usecols=file2_columns)   
        # file3 = pd.read_excel(file3_path, usecols=file3_columns)                            
              
        # 使用pd.concat()函数将三个DataFrame横向合并    
        merged_df = pd.concat([file1, file2, file3], axis=1)    
                
        # 将合并后的DataFrame保存到新的Excel文件中，并存放到指定的文件夹    
        output_path = os.path.join(output_folder, f"{security_code}")    
        merged_df.to_excel(output_path, index=False)  
    else:  
        print(f"One or more files for {security_code} do not exist. Skipping...")  
        continue

# %%
import os  
import pandas as pd  
   
folder1 = '国企沪市的季频偿债能力'  
folder2 = '国企沪市的季频现金流数据'  
folder3 = '国企沪市的季频盈利能力'  
  

output_folder = '国企沪市的三合一'  
  

security_codes = os.listdir(folder1)  
for security_code in security_codes:    
    # 初始化一个标志变量，用于记录三个文件是否都存在  
    all_files_exist = True  
  
    # 检查文件是否在三个文件夹中都存在    
    file1_path = os.path.join(folder1, security_code)    
    file2_path = os.path.join(folder2, security_code)    
    file3_path = os.path.join(folder3, security_code)    
  
    # 检查三个文件是否存在，并且是否是Excel文件  
    if not (os.path.isfile(file1_path) and os.path.isfile(file2_path) and os.path.isfile(file3_path)):    
        all_files_exist = False  
    else:  
        # 如果是Excel文件（这里假设所有文件都是.xlsx格式）    
        if not (file1_path.endswith('.xlsx') and file2_path.endswith('.xlsx') and file3_path.endswith('.xlsx')):    
            all_files_exist = False  
  
    # 如果所有文件都存在，才执行后续的操作  
    if all_files_exist:  
        # 从三个Excel文件中抽取指定列    
        # 从第一个表格中抽取指定列
         
        file1_columns = ["年份", "季度", "证券代码", "公司发布财报的日期", "财报统计的季度的最后一天", "流动比率", "速动比率", "现金比率", "总负债同比增长率", "资产负债率", "权益乘数"]  
        try: 
            file1 = pd.read_excel(file1_path, usecols=file1_columns)  
        except:
            print(f"{file1_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第二个表格中抽取指定列  
        
        file2_columns = ["流动资产除以总资产", "有形资产除以总资产", "已获利息倍数", "经营活动产生的现金流量净额除以营业收入", "经营性现金净流量除以净利润", "	经营性现金净流量除以营业总收入"]  
        try: 
            file2 = pd.read_excel(file2_path, usecols=file2_columns) 
        except:
            print(f"{file2_path}缺少一些列，从而跳过处理...") 
            continue
        # 从第三个表格中抽取指定列  
        file3_columns = ["净资产收益率(平均)(%)", "销售净利率(%)", "销售毛利率(%)", "净利润(元)", "每股收益", "主营营业收入(元)", "总股本", "流通股本"]  
        try:
            file3 = pd.read_excel(file3_path, usecols=file3_columns) 
        except: 
            print(f"{file3_path}缺少一些列，从而跳过处理...") 
            continue      
        
        # file1 = pd.read_excel(file1_path, usecols=file1_columns)     
        # file2 = pd.read_excel(file2_path, usecols=file2_columns)   
        # file3 = pd.read_excel(file3_path, usecols=file3_columns)                            
              
        # 使用pd.concat()函数将三个DataFrame横向合并    
        merged_df = pd.concat([file1, file2, file3], axis=1)    
                
        # 将合并后的DataFrame保存到新的Excel文件中，并存放到指定的文件夹    
        output_path = os.path.join(output_folder, f"{security_code}")    
        merged_df.to_excel(output_path, index=False)  
    else:  
        print(f"One or more files for {security_code} do not exist. Skipping...")  
        continue
